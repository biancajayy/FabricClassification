# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow import keras
from tensorflow.keras import layers

# %%
#PREPROCESSING
#Get images 

training_data_path = 'images/train'
testing_data_path = 'images/test'
validation_data_path = 'images/validation'

# %%
# fit images to the same size

image_height = 200
image_width = 200

# %%
# function to convert path to greyscaled dataset
def dataset_dir(data_path):
    return tf.keras.utils.image_dataset_from_directory(
        data_path,
        batch_size= 4,
        shuffle=True,
        color_mode= 'rgb',
        image_size= (image_width, image_height),
        validation_split= False)

# %%
training_data = dataset_dir(training_data_path)
# Out:
# Found 226 files belonging to 3 classes.

# %%
categories = training_data.class_names
#print(categories)

# %%
testing_data = dataset_dir(testing_data_path)
# Out:
# Found 30 files belonging to 3 classes.

# %%
validation_data = dataset_dir(validation_data_path)
# Out:
# Found 30 files belonging to 3 classes.

# %%
#Show image of each type

plt.figure(figsize=(10,10))
for training_data_point in training_data.take(1):
    images, cat = training_data_point
    for i in range(4):
        plt.subplot(2, 2, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(categories[cat[i]])
# Out:
# 2024-08-05 22:47:01.587369: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# CREATING THE MODEL

from tensorflow.keras.models import Sequential


#standard sequntial model from tensorflow keras documentation
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dense(3, activation= 'sigmoid')
    
])

# %%
model.compile(optimizer= 'rmsprop',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model with n epochs

epochs=35
history = model.fit(
    training_data, 
    validation_data=validation_data,
    epochs=epochs
)
# Out:
# Epoch 1/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.4460 - loss: 1.9139 - val_accuracy: 0.6000 - val_loss: 0.8421
# Epoch 2/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.5580 - loss: 0.8017 - val_accuracy: 0.7000 - val_loss: 0.6567
# Epoch 3/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7136 - loss: 0.7296 - val_accuracy: 0.7000 - val_loss: 0.8187
# Epoch 4/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7238 - loss: 0.9026 - val_accuracy: 0.7333 - val_loss: 0.5909
# Epoch 5/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.7421 - loss: 0.6769 - val_accuracy: 0.7000 - val_loss: 0.6253
# Epoch 6/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7658 - loss: 0.5657 - val_accuracy: 0.8000 - val_loss: 0.5606
# Epoch 7/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7500 - loss: 0.5574 - val_accuracy: 0.7000 - val_loss: 0.6195
# Epoch 8/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7125 - loss: 0.6002 - val_accuracy: 0.8000 - val_loss: 0.5040
# Epoch 9/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7516 - loss: 0.6331 - val_accuracy: 0.7333 - val_loss: 0.4895
# Epoch 10/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.7614 - loss: 0.5822 - val_accuracy: 0.7000 - val_loss: 0.6247
# Epoch 11/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7875 - loss: 0.5187 - val_accuracy: 0.8000 - val_loss: 0.5642
# Epoch 12/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8181 - loss: 0.4530 - val_accuracy: 0.8333 - val_loss: 0.4428
# Epoch 13/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8218 - loss: 0.4970 - val_accuracy: 0.7000 - val_loss: 0.9188
# Epoch 14/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8145 - loss: 0.4323 - val_accuracy: 0.7333 - val_loss: 0.5603
# Epoch 15/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8513 - loss: 0.4585 - val_accuracy: 0.8000 - val_loss: 0.4908
# Epoch 16/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8706 - loss: 0.3033 - val_accuracy: 0.7333 - val_loss: 0.4989
# Epoch 17/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.7704 - loss: 0.5449 - val_accuracy: 0.8333 - val_loss: 0.5328
# Epoch 18/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8787 - loss: 0.3294 - val_accuracy: 0.8000 - val_loss: 0.6827
# Epoch 19/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8629 - loss: 0.4236 - val_accuracy: 0.6333 - val_loss: 0.5737
# Epoch 20/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8671 - loss: 0.3229 - val_accuracy: 0.8000 - val_loss: 0.4288
# Epoch 21/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8585 - loss: 0.3717 - val_accuracy: 0.7333 - val_loss: 0.5834
# Epoch 22/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8650 - loss: 0.3458 - val_accuracy: 0.6667 - val_loss: 1.1950
# Epoch 23/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.8605 - loss: 0.4136 - val_accuracy: 0.8000 - val_loss: 0.5240
# Epoch 24/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9236 - loss: 0.3036 - val_accuracy: 0.7000 - val_loss: 0.6424
# Epoch 25/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8565 - loss: 0.3708 - val_accuracy: 0.8333 - val_loss: 0.6361
# Epoch 26/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8737 - loss: 0.3195 - val_accuracy: 0.8000 - val_loss: 0.4672
# Epoch 27/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9175 - loss: 0.2330 - val_accuracy: 0.7333 - val_loss: 0.7113
# Epoch 28/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8804 - loss: 0.3344 - val_accuracy: 0.8333 - val_loss: 0.5514
# Epoch 29/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9009 - loss: 0.3096 - val_accuracy: 0.8000 - val_loss: 0.6940
# Epoch 30/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8834 - loss: 0.3117 - val_accuracy: 0.7667 - val_loss: 0.5217
# Epoch 31/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8827 - loss: 0.3053 - val_accuracy: 0.7667 - val_loss: 0.5856
# Epoch 32/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8900 - loss: 0.2388 - val_accuracy: 0.7333 - val_loss: 0.6735
# Epoch 33/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8949 - loss: 0.2895 - val_accuracy: 0.6667 - val_loss: 1.4353
# Epoch 34/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9013 - loss: 0.2981 - val_accuracy: 0.7667 - val_loss: 0.7632
# Epoch 35/35
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9251 - loss: 0.2128 - val_accuracy: 0.8333 - val_loss: 0.8767

# %%
model.evaluate(testing_data)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7782 - loss: 0.4916
# [0.5460270643234253, 0.7666666507720947]

# %%
epochs_range = range(epochs)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
plt.show()

# %%
test_image = 'Linen.jpg'
image = tf.keras.utils.load_img(test_image, target_size=(image_height,image_width))
image_array = tf.keras.utils.array_to_img(image)
img_exp = tf.expand_dims(image_array, 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 test_image = 'Linen.jpg'
# ----> 2 image = tf.keras.utils.load_img(test_image, target_size=(image_height,image_width))
#       3 image_array = tf.keras.utils.array_to_img(image)
#       4 img_exp = tf.expand_dims(image_array, 0)
#
# File ~/miniconda3/lib/python3.11/site-packages/keras/src/utils/image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Linen.jpg'

# %%
prediction = model.predict(img_exp)

# %%
accuracy = tf.nn.softmax(prediction)

# %%
print('The fabric shown is {}. This is predicted with {:0.2f} accuracy.'.format(categories[np.argmax(accuracy)], np.max(accuracy)*100))
