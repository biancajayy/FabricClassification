# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
#PREPROCESSING
#Get images 

training_data_path = 'images/train'
testing_data_path = 'images/test'
validation_data_path = 'images/validation'

# %%
# fit images to the same size

image_height = 180
image_width = 180

# %%
# function to convert path to greyscaled dataset
def dataset_dir(data_path):
    return tf.keras.utils.image_dataset_from_directory(
        data_path,
        batch_size= 4,
        shuffle=True,
        image_size= (image_width, image_height),
        validation_split= False)

# %%
training_data = dataset_dir(training_data_path)
# Out:
# Found 177 files belonging to 2 classes.

# %%
categories = training_data.class_names
#print(categories)

# %%
testing_data = dataset_dir(testing_data_path)
# Out:
# Found 20 files belonging to 2 classes.

# %%
validation_data = dataset_dir(validation_data_path)
# Out:
# Found 20 files belonging to 2 classes.

# %%
#Show image of each type

plt.figure(figsize=(10,10))
for training_data_point in training_data.take(1):
    images, cat = training_data_point
    for i in range(4):
        plt.subplot(2, 2, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(categories[cat[i]])

# %%
#augement data frore more training data

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

# %%
# Visualization of augmented images
def visualize_augmented_images(images):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        augmented_image = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_image[0].numpy().astype('uint8'), cmap='gray')
        plt.axis("off")
    plt.show()

# Select a batch of images from the training data for visualization
for training_data_point in training_data.take(1):
    images, cat = training_data_point
    images = tf.cast(images, tf.float32)
    visualize_augmented_images(images)

# %%
# CREATING THE MODEL

from tensorflow.keras.models import Sequential


#standard sequntial model from tensorflow keras documentation
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(4)
    
])

# %%
model.compile(optimizer='Adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Fit the model with n epochs

epochs=25
history = model.fit(
    training_data, 
    validation_data=validation_data,
    epochs=epochs
)
# Out:
# Epoch 1/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5589 - loss: 2.0268 - val_accuracy: 0.9500 - val_loss: 0.3027
# Epoch 2/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8899 - loss: 0.3028 - val_accuracy: 0.8500 - val_loss: 0.3958
# Epoch 3/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8630 - loss: 0.3667 - val_accuracy: 0.9000 - val_loss: 0.2335
# Epoch 4/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8707 - loss: 0.3518 - val_accuracy: 0.8000 - val_loss: 0.3314
# Epoch 5/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8408 - loss: 0.4279 - val_accuracy: 1.0000 - val_loss: 0.1633
# Epoch 6/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9518 - loss: 0.1923 - val_accuracy: 0.8500 - val_loss: 0.2549
# Epoch 7/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9213 - loss: 0.2995 - val_accuracy: 0.9500 - val_loss: 0.1908
# Epoch 8/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9112 - loss: 0.2062 - val_accuracy: 1.0000 - val_loss: 0.0858
# Epoch 9/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8614 - loss: 0.3501 - val_accuracy: 1.0000 - val_loss: 0.0996
# Epoch 10/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8750 - loss: 0.3139 - val_accuracy: 0.9500 - val_loss: 0.1960
# Epoch 11/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9198 - loss: 0.2112 - val_accuracy: 0.9500 - val_loss: 0.1180
# Epoch 12/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8559 - loss: 0.4063 - val_accuracy: 0.8500 - val_loss: 0.2998
# Epoch 13/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8487 - loss: 0.2794 - val_accuracy: 0.9500 - val_loss: 0.1139
# Epoch 14/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8604 - loss: 0.2603 - val_accuracy: 1.0000 - val_loss: 0.1097
# Epoch 15/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9370 - loss: 0.1691 - val_accuracy: 1.0000 - val_loss: 0.0881
# Epoch 16/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9318 - loss: 0.1613 - val_accuracy: 0.9000 - val_loss: 0.1950
# Epoch 17/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8608 - loss: 0.3409 - val_accuracy: 1.0000 - val_loss: 0.1114
# Epoch 18/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9493 - loss: 0.1473 - val_accuracy: 1.0000 - val_loss: 0.0871
# Epoch 19/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9145 - loss: 0.1708 - val_accuracy: 1.0000 - val_loss: 0.0711
# Epoch 20/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9308 - loss: 0.1914 - val_accuracy: 1.0000 - val_loss: 0.1341
# Epoch 21/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9447 - loss: 0.1966 - val_accuracy: 1.0000 - val_loss: 0.2207
# Epoch 22/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9659 - loss: 0.1461 - val_accuracy: 0.9000 - val_loss: 0.2316
# Epoch 23/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9183 - loss: 0.2319 - val_accuracy: 0.9500 - val_loss: 0.0777
# Epoch 24/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9863 - loss: 0.0929 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 25/25
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9266 - loss: 0.1540 - val_accuracy: 0.8000 - val_loss: 0.3522

# %%
model.evaluate(testing_data)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7250 - loss: 0.5723
# [0.44250303506851196, 0.800000011920929]
