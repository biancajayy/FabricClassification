# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow import keras
from tensorflow.keras import layers

# %%
#PREPROCESSING
#Get images 

training_data_path = 'images/train'
testing_data_path = 'images/test'
validation_data_path = 'images/validation'

# %%
# fit images to the same size

image_height = 200
image_width = 200

# %%
# function to convert path to greyscaled dataset
def dataset_dir(data_path):
    return tf.keras.utils.image_dataset_from_directory(
        data_path,
        batch_size= 4,
        shuffle=True,
        color_mode= 'rgb',
        image_size= (image_width, image_height),
        validation_split= False)

# %%
training_data = dataset_dir(training_data_path)
# Out:
# Found 226 files belonging to 3 classes.

# %%
categories = training_data.class_names
#print(categories)

# %%
testing_data = dataset_dir(testing_data_path)
# Out:
# Found 30 files belonging to 3 classes.

# %%
validation_data = dataset_dir(validation_data_path)
# Out:
# Found 30 files belonging to 3 classes.

# %%
#Show image of each type

plt.figure(figsize=(10,10))
for training_data_point in training_data.take(1):
    images, cat = training_data_point
    for i in range(4):
        plt.subplot(2, 2, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(categories[cat[i]])
# Out:
# 2024-08-01 15:51:20.455662: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# CREATING THE MODEL

from tensorflow.keras.models import Sequential


#standard sequntial model from tensorflow keras documentation
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, (3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dense(3, activation= 'sigmoid')
    
])

# %%
model.compile(optimizer= 'rmsprop',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model with n epochs

epochs=40
history = model.fit(
    training_data, 
    validation_data=validation_data,
    epochs=epochs
)
# Out:
# Epoch 1/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.3812 - loss: 2.4356 - val_accuracy: 0.3333 - val_loss: 1.1363
# Epoch 2/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.4709 - loss: 1.0614 - val_accuracy: 0.6333 - val_loss: 0.9501
# Epoch 3/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6506 - loss: 0.8774 - val_accuracy: 0.4000 - val_loss: 2.1933
# Epoch 4/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.6186 - loss: 0.9576 - val_accuracy: 0.6000 - val_loss: 1.1725
# Epoch 5/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6754 - loss: 0.8057 - val_accuracy: 0.7667 - val_loss: 0.6570
# Epoch 6/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.6578 - loss: 0.8357 - val_accuracy: 0.7333 - val_loss: 0.6968
# Epoch 7/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7125 - loss: 0.6812 - val_accuracy: 0.7333 - val_loss: 0.7316
# Epoch 8/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7184 - loss: 0.7040 - val_accuracy: 0.7667 - val_loss: 0.6185
# Epoch 9/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7379 - loss: 0.7038 - val_accuracy: 0.7000 - val_loss: 0.7023
# Epoch 10/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.7316 - loss: 0.6816 - val_accuracy: 0.6667 - val_loss: 0.8069
# Epoch 11/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7077 - loss: 0.6811 - val_accuracy: 0.7000 - val_loss: 0.6283
# Epoch 12/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.7939 - loss: 0.5309 - val_accuracy: 0.6333 - val_loss: 0.9990
# Epoch 13/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8283 - loss: 0.5792 - val_accuracy: 0.7000 - val_loss: 0.8237
# Epoch 14/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7857 - loss: 0.8268 - val_accuracy: 0.7333 - val_loss: 0.6485
# Epoch 15/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8296 - loss: 0.6305 - val_accuracy: 0.7000 - val_loss: 0.7177
# Epoch 16/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8505 - loss: 0.5857 - val_accuracy: 0.6333 - val_loss: 1.3747
# Epoch 17/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8097 - loss: 0.6049 - val_accuracy: 0.6333 - val_loss: 0.7364
# Epoch 18/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8239 - loss: 0.5118 - val_accuracy: 0.8000 - val_loss: 0.7569
# Epoch 19/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8325 - loss: 0.5084 - val_accuracy: 0.7000 - val_loss: 0.5898
# Epoch 20/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8388 - loss: 0.4103 - val_accuracy: 0.7333 - val_loss: 0.5871
# Epoch 21/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8363 - loss: 0.4330 - val_accuracy: 0.6333 - val_loss: 0.9321
# Epoch 22/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8909 - loss: 0.3772 - val_accuracy: 0.7000 - val_loss: 1.3243
# Epoch 23/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8769 - loss: 0.3187 - val_accuracy: 0.6667 - val_loss: 1.2612
# Epoch 24/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8393 - loss: 0.4297 - val_accuracy: 0.8333 - val_loss: 0.5628
# Epoch 25/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9002 - loss: 0.3394 - val_accuracy: 0.7667 - val_loss: 1.0679
# Epoch 26/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.8674 - loss: 0.4257 - val_accuracy: 0.6333 - val_loss: 1.2368
# Epoch 27/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8833 - loss: 0.2421 - val_accuracy: 0.8333 - val_loss: 0.7000
# Epoch 28/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9359 - loss: 0.2021 - val_accuracy: 0.8000 - val_loss: 0.7546
# Epoch 29/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9123 - loss: 0.2238 - val_accuracy: 0.7000 - val_loss: 0.9725
# Epoch 30/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8943 - loss: 0.2923 - val_accuracy: 0.8333 - val_loss: 0.6175
# Epoch 31/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9204 - loss: 0.2218 - val_accuracy: 0.6333 - val_loss: 1.7118
# Epoch 32/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8972 - loss: 0.3595 - val_accuracy: 0.7000 - val_loss: 1.5120
# Epoch 33/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8975 - loss: 0.2731 - val_accuracy: 0.5667 - val_loss: 1.9831
# Epoch 34/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8643 - loss: 0.4069 - val_accuracy: 0.9000 - val_loss: 1.0082
# Epoch 35/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9057 - loss: 0.3709 - val_accuracy: 0.9000 - val_loss: 0.8264
# Epoch 36/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9512 - loss: 0.1654 - val_accuracy: 0.8333 - val_loss: 0.6029
# Epoch 37/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9104 - loss: 0.2476 - val_accuracy: 0.8333 - val_loss: 0.5036
# Epoch 38/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9616 - loss: 0.1277 - val_accuracy: 0.8333 - val_loss: 0.7669
# Epoch 39/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9436 - loss: 0.2016 - val_accuracy: 0.8333 - val_loss: 0.8748
# Epoch 40/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9034 - loss: 0.3080 - val_accuracy: 0.8333 - val_loss: 1.2325

# %%
model.evaluate(testing_data)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8097 - loss: 0.5645
# [0.6321364045143127, 0.7333333492279053]
